# %%
# !pip install google-play-scraper
# !pip install pandas
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# Mengambil semua ulasan dari aplikasi MiChat dengan ID 'com.michat.im' di Google Play Store.
scrapreview = reviews_all(
    'com.michatapp.im',      # ID aplikasi
    lang='id',               # Bahasa ulasan (menggunakan 'id' bahasa indonesia)
    country='id',            # Negara ('id' negara indonesia)
    sort=Sort.NEWEST,        # Urutan ulasan ('NEWEST' artinya terbaru)
    count=40000              # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_michat.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik
seed = 0
np.random.seed(seed)  # Mengatur seed untuk reproduktibilitas

app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_michat.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  2bc49f9e-f828-4739-9c95-2a0754d6a010  Pengguna Google
# 1  196457ef-8058-489a-9269-9ab4bbcf2a69  Pengguna Google
# 2  a9771057-c3b2-432d-9e06-f99469483989  Pengguna Google
# 3  a77b1a08-baae-46b3-b60e-292ecc831c8b  Pengguna Google
# 4  f85da1fd-de90-4525-a2ab-2dd36f6268a9  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                      Baguus sekali sengng pakia in      3              0
# 1                             Kebanyakan iklan bosen      1              0
# 2      tolong munculkan pengguna sekitar dan penyapa      2              0
# 3                              Iklan iklan dan iklan      1              0
# 4  Terlalu banyak iklannya sehingga sangat mengga...      2              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0              1.4.525 2025-01-13 16:16:07         None       NaT    1.4.525
# 1              1.4.525 2025-01-13 16:13:38         None       NaT    1.4.525
# 2              1.4.525 2025-01-13 16:02:08         None       NaT    1.4.525
# 3              1.4.525 2025-01-13 15:45:59         None       NaT    1.4.525
# 4                 None 2025-01-13 15:42:06         None       NaT       None

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324000 entries, 0 to 323999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              324000 non-null  object
#  1   userName              324000 non-null  object
#  2   userImage             324000 non-null  object
#  3   content               324000 non-null  object
#  4   score                 324000 non-null  int64
#  5   thumbsUpCount         324000 non-null  int64
#  6   reviewCreatedVersion  222246 non-null  object
#  7   at                    324000 non-null  datetime64[ns]
#  8   replyContent          349 non-null     object
#  9   repliedAt             349 non-null     datetime64[ns]
#  10  appVersion            222246 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 27.2+ MB

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menampilkan informasi tentang DataFrame clean_df setelah membersihkan nilai yang hilang (NaN)
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 315 entries, 4022 to 323905
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              315 non-null    object
#  1   userName              315 non-null    object
#  2   userImage             315 non-null    object
#  3   content               315 non-null    object
#  4   score                 315 non-null    int64
#  5   thumbsUpCount         315 non-null    int64
#  6   reviewCreatedVersion  315 non-null    object
#  7   at                    315 non-null    datetime64[ns]
#  8   replyContent          315 non-null    object
#  9   repliedAt             315 non-null    datetime64[ns]
#  10  appVersion            315 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 29.5+ KB

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()

# Menghitung jumlah baris dan kolom dalam DataFrame clean_df setelah menghapus duplikat
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape
